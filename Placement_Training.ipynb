# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhijith-1010/placement-S7/blob/main/Placement_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def monkey_bal():
  try:
    n=int(input())
    k=int(input())
    j=int(input())
    m=int(input())
    p=int(input())
    if n<0 or k<=0 or j<=0 or m<0 or p<0:
      print("INVALID INPUT")
      return

    ate_bananas = m/k
    ate_peanuts = p/j
    total_ate = ate_bananas + ate_peanuts

    if (m % k) != 0 or (p % j) != 0:
      total_ate+=1

    monkeys_bal = n - total_ate
    if monkeys_bal < 0:
      monkeys_bal = 0

    print(f"number of monkeys left on the tree:{monkeys_bal}")

  except ValueError:
    print("INVALID INPUT")

if __name__ == "__main__":
  monkey_bal()
# Out:
# 20
# 2
# 3
# 12
# 12
# number of monkeys left on the tree:10.0

# %%
a=int(input("enter the number first "))
b=int(input("enter the number second "))
print ("condition using + and -")
a=a+b
b=a-b
a=a-b
print ("swap 1 a =",a)
print ("swap 1 b =",b)
print ("condition using xor")
a=a^b
b=a^b
a=a^b
print ("swap 2 a =",a)
print ("swap 2 b =",b)
print ("condition using ,")
a,b=b,a
print ("swap 3 a =",a)
print ("swap 3 b =",b)
print ("condition using temp")
temp=a
a=b
b=temp
print ("swap 4 a =",a)
print ("swap 4 b =",b)
# Out:
# enter the number first 10
# enter the number second 20
# condition using + and -
# swap 1 a = 20
# swap 1 b = 10
# condition using xor
# swap 2 a = 10
# swap 2 b = 20
# condition using ,
# swap 3 a = 20
# swap 3 b = 10
# condition using temp
# swap 4 a = 10
# swap 4 b = 20

# %%
n=int(input("Enter max no. of candies:"))
k=int(input("Enter min no. of candies:"))
c=1
r=n
while(c==1):
  m=int(input("Enter amout of candies needed:"))
  if(m>n):
    print("invalid")
  else:
    r=r-m
    if(r<=k):
      r=n
    print("SOLD=",m)
    print("Remaining=",r)
    C=int(input("DO you want to continue(1or0):"))
# Out:
# Enter max no. of candies:10
# Enter min no. of candies:5
# Enter amout of candies needed:3
# SOLD= 3
# Remaining= 7
# DO you want to continue(1or0):1

# %%
l=[]
x=int(input("Enter the size:"))
for i in range(0,x):
  l.append(input("Enter the elements:"))
for i in range(0,x):
  print(l[i])
# Out:
# Enter the size:4
# Enter the elements:2
# Enter the elements:6
# Enter the elements:4
# Enter the elements:78
# 2
# 6
# 4
# 78

# %%
n=int(input("Enter the no of elements"))
a=[]
for i in range(n):
  m=int(input("Enter the element"))
  a.append(m)
  print(a)
print("the largest element is",max(a))
# Out:
# enter the number of elements4
# enter the element7
# [7]
# enter the element8
# [7, 8]
# enter the element9
# [7, 8, 9]
# enter the element10
# [7, 8, 9, 10]
# the largest element is 10

# %%
n=int(input("Enter the no of elements"))
a=[]
for i in range(n):
  m=int(input("Enter the element"))
  a.append(m)
  print(a)
print("the smallest element is",min(a))
# Out:
# Enter the no of elements4
# Enter the element7
# [7]
# Enter the element8
# [7, 8]
# Enter the element9
# [7, 8, 9]
# Enter the element10
# [7, 8, 9, 10]
# the smallest element is 7

# %%
n=int(input("Enter the no of elements:"))
a=[]
for _ in range(n):
  m=int(input("Enter the element"))
  a.append(m)
sum = 0
for element in a:
  sum += element
print("sum:", sum)
# Out:
# Enter the no of elements:2
# Enter the element6
# Enter the element4
# sum: 10

# %%
n = int(input("Enter no of elements: "))
a = []
for i in range(n):
  m=int(input("Enter the element: "))
  a.append(m)
  print(a)
print("reversed array",a[::-1])
# Out:
# Enter no of elements: 4
# Enter the element: 1
# [1]
# Enter the element: 2
# [1, 2]
# Enter the element: 3
# [1, 2, 3]
# Enter the element: 4
# [1, 2, 3, 4]
# reversed array [4, 3, 2, 1]

# %%
l=[]
n=int(input("Enter the no of elements: "))
for i in range(n):
  a=int(input("Enter element: "))
  l.append(a)
a=int(input("Enter the element to be searched "))
if a in l:
  print("Element exists")
else:
  print("Element does not exist")
# Out:
# Enter the no of elements: 4
# Enter element: 3
# Enter element: 6
# Enter element: 8
# Enter element: 9
# Enter the element to be searched 8
# Element exists

# %%
l= []
x = int(input("Enter the limit: "))
for i in range(x):
    l.append(int(input("Enter the item: ")))
y = int(input("Enter the element: "))
count = l.count(y)
print("Occurrences:", count)
# Out:
# Enter the limit: 5
# Enter the item: 3
# Enter the item: 7
# Enter the item: 8
# Enter the item: 5
# Enter the item: 2
# Enter the element: 2
# Occurrences: 1

# %%
l=[]
n=int(input("Enter the no of elements:"))
for i in range(n):
  m=int(input("Enter the element: "))
  l.append(m)
print(l)
l.sort()
print("sorted array:",l)
print("second largest number:",l[-2])
# Out:
# Enter the no of elements:4
# Enter the element: 8
# Enter the element: 3
# Enter the element: 5
# Enter the element: 9
# [8, 3, 5, 9]
# sorted array: [3, 5, 8, 9]
# second largest number: 8

# %%
l=[]
n=int(input("Enter the no of elements: "))
for i in range(n):
  m=int(input("Enter the element: "))
  l.append(m)
print(l)
print(list(set(l)))
# Out:
# Enter the no of elements: 4
# Enter the element: 3
# Enter the element: 5
# Enter the element: 6
# Enter the element: 3
# [3, 5, 6, 3]
# [3, 5, 6]

# %%
l=[]
n=int(input("Enter the no of elements: "))
for i in range(n):
  m=int(input("Enter the element: "))
  l.append(m)
l.sort()
print("Sorted Array ",l)
# Out:
# Enter the no of elements: 4
# Enter the element: 2
# Enter the element: 6
# Enter the element: 9
# Enter the element: 3
# Sorted Array  [2, 3, 6, 9]

# %%
l = list(map(int, input("Enter array elements: ").split()))
print(l)
# Out:
# Enter array elements: 4
# [4]

# %%
arr =[10,20,30,40,50]
print(arr[1:4])
print(arr[:3])
print(arr[2:])
print(arr[::-1])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50]
# [50, 40, 30, 20, 10]

# %%
r=int(input("Enter the no of rats:"))
u=int(input("Enter the no of units:"))
n=int(input("Enter the no of elements:"))
arr=list(map(int,input("Enter the array").split()))
b=0
h=0
for i in range(0,len(arr)):
  h+=1
  b=b+arr[i]
  if b>=r*u:
    break
print("No of houses:",h)
# Out:
# Enter the no of rats:7
# Enter the no of units:2
# Enter the no of elements:8
# Enter the array2 8 3 5 7 4 1 2
# No of houses: 4

# %%
s = input("Enter a string: ")
s1 = s[::-1]
print(s1)
# Out:
# Enter a string: 2 3 4
# 4 3 2

# %%
n = input("Enter a number: ")
n1 = n[::-1]
print(n1)
# Out:
# Enter a number: 123
# 321

# %%
n= int(input("Enter a number: "))
s = 0
while n > 0:
    s += n % 10
    n //= 10
print("sum:",s)
# Out:
# Enter a number: 12345
# sum: 15

# %%
number = int(input("Enter a number: "))
largest = 0
while number > 0:
    digit = number % 10
    if digit > largest:
        largest = digit
    number = number // 10
print("large no:",largest)
# Out:
# Enter a number: 124567
# large no: 7

# %%
n = int(input("Enter a number: "))
original = n
rev_n = 0
while n > 0:
    digit = n % 10
    rev_n = (rev_n * 10) + digit
    n = n // 10
if original == rev_n:
    print("Palindrome")
else:
    print("Not a Palindrome")
# Out:
# Enter a number: 121
# Palindrome

# %%
s = input("Enter a string: ")
if s == s[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Enter a string: abba
# Palindrome

# %%
s1 = input("Enter a string: ")
s2 = input("Enter a string: ")
if sorted(s1) == sorted(s2):
    print("Anagram")
else:
    print("Not an Anagram")
# Out:
# Enter a string: abc
# Enter a string: abc
# Anagram

# %%
s=input("Ënter a string:")
print("Length with built in:",len(s))
c=0
for i in s:
  c=c+1
print("Length without built in:",c)
# Out:
# Ënter a string:acba
# Length with built in: 4
# Length without built in: 4

# %%
s = input("Enter a string: ")
result = ""
for c in s:
    if c not in result:
        result += c
print(result)
# Out:
# Enter a string: abda
# abd

# %%
s = input("Enter a string: ")
v = 0
c = 0
vowels = "aeiouAEIOU"
for char in s:
        if char in vowels:
            v += 1
        else:
            c += 1
print("Vowels:", v)
print("Consonants:", c)
# Out:
# Enter a string: abcde
# Vowels: 2
# Consonants: 3

# %%
s = input("Enter a string: ")
result = ""
for c in s:
    if c != " ":
        result += c
print(result)
# Out:
# Enter a string: a b c d
# abcd
